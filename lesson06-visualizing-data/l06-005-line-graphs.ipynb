# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

def load_flights():
    column_names = ['year', 'month', 'passengers']
    data = pd.read_csv('flights.csv', header=0, names=column_names)
    return data

# flights_long=sns.load_dataset("flights") # Take default data from seaborn

flights_long=load_flights() # Load data from local file

print(flights_long.head())

flights_long=flights_long[flights_long.month=='January']

plot=sns.lineplot(data=flights_long, x="year", y="passengers")
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121
